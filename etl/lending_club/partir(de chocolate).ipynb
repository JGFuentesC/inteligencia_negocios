# %%
import numpy as np
import pandas as pd 
import json
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('data/acc.csv',dtype=str,nrows=1000)

# %%
df.head(2)
# Out:
#          id member_id loan_amnt funded_amnt funded_amnt_inv        term  \
# 0  68407277       NaN    3600.0      3600.0          3600.0   36 months
# 1  68355089       NaN   24700.0     24700.0         24700.0   36 months
#
#   int_rate installment grade sub_grade emp_title emp_length home_ownership  \
# 0    13.99      123.03     C        C4   leadman  10+ years       MORTGAGE
# 1    11.99      820.28     C        C1  Engineer  10+ years       MORTGAGE
#
#   annual_inc verification_status   issue_d loan_status pymnt_plan  \
# 0    55000.0        Not Verified  Dec-2015  Fully Paid          n
# 1    65000.0        Not Verified  Dec-2015  Fully Paid          n
#
#                                                  url desc             purpose  \
# 0  https://lendingclub.com/browse/loanDetail.acti...  NaN  debt_consolidation
# 1  https://lendingclub.com/browse/loanDetail.acti...  NaN      small_business
#
#                 title zip_code addr_state    dti delinq_2yrs earliest_cr_line  \
# ...

# %%
df.shape
# Out:
# (1000, 151)

# %%
cols = ['id','loan_amnt','term',
        'sub_grade','emp_title',
        'home_ownership','annual_inc',
        'issue_d','loan_status','purpose','addr_state','dti',
        'inq_last_6mths','total_acc',
        'num_accts_ever_120_pd'
        ]

# %%
df = df[cols]

# %%
muestra = df.sample(20).reset_index(drop=True)

# %%
## Mala práctica, no iteren un dataframe
for _,row in muestra.iterrows():
    json.dump(row.to_dict(),open(f'data/json/{row["id"]}.json','w'))
